# %%
#CALCULANDO E IMPRIMINDO A MÉDIA
#nota1 = int (input("Digita a primeira nota: "))
#nota2 = int (input("Digita a segunda nota: "))
#nota3 = int (input("Digita a terceira nota: "))
#nota4 = int (input("Digita a quarta nota: "))

#media = (nota1 + nota2 + nota3 + nota4) / 4

#print(f'A sua média final é {media}')

#CALCULANDO O VOLUME
#cumprimento = float (input("Digite o comprimento(m): "))
#largura = float (input("Digite a largura(m): "))
#altura = float (input("Digite a altura(m): "))

#volume = cumprimento * largura * altura
#print(f'O volume do paralelepipedo é {volume}')

#ADIÇÃO, SUBTRAÇÃO, MULTIPLICAÇÃO E DIVISÃO
#n1 = int (input('Digite um número: '))
#n2 = int (input('Digite outro número: '))

#adição
#soma = n1 + n2
#print(f'A soma dos números escolhidos é {soma}')

#subtração
#sub = n1 - n2
#print(f'A subtração dos números escolhidos é {sub}')

#multiplicação
#mult = n1 * n2
#print(f'A multiplicação dos números escolhidos é {mult}')

#divisão
#div = n1 / n2
#print(f'A divisão dos números escolhidos é {div}')

#CONVERTENDO TEMPERATURA DE FAHRENHEIT PARA CELSIUS

#fahr = int (input('Digite a temperatura em Fahrenheit: '))

#temp = (fahr - 32) * 5 / 9

#print(f'A temperatura em Fahrenheit é {fahr}F --> A temperatura em Celsius é {temp}°C')

#CALCULANDO O VOLUME DE UMA LATA DE ÓLEO
#import math
#r = float (input('Digite o raio da lata de óleo: '))
#alt = float (input('Digite a altura da lata de óleo: '))
#pia = math.pi
#volume = pia * r**2 * alt
#print(f'O volume da lata de óleo é: {volume}')

#TROCANDO DE VALORES
#nu1 = int (input('Digite um valor: '))
#print(f'O valor escolhido é: {n1}')
#nu2 = int (input('Digite outro valor: '))
#print(f'O valor escolhido é: {n2}')
#n1 = nu2
#print(n1)
#nue2 = nu1
#print(nue2)

#Taxação sobre valor
#n1 = float (input('Digite o valor: '))
#n2 = int (input('Digite o tempo em dias: '))
#prestacao = n1 + (n1 * (2/100) * n2)
#print(f'O novo falar da prestação em atraso é de R${prestacao}')

#Faça um programa que receba o valor de um depósito e o valor da taxa de juros. 
#Calcule e imprima o valor do rendimento e o valor total depois do rendimento.
#dep = float (input('Digite o valor a ser depositado: '))
#tx_juro = float (input('Digite a taxa de juros: '))
#tempo = int (input('Digite a quantidade de meses que pretende deixar investido: '))
#rend_total = dep + (dep * (tx_juro/100)* tempo)
#red = dep * (tx_juro/100)
#print(f'O rendimento mensal será de {red}')
#print(f'Seu dinheiro no final de {tempo} meses irá render R${rend_total}')

#TABUADA
#i = int (input('Digite um número: '))
#for n in range(11): 
#  print(f'{n} x {i} = {n * i}')

#SALÁRIO 
#salario = float (input('Digite o seu salário R$:'))
#salario_min = 1100
#dif = salario // salario_min
#print(f'Seu salário corresponde a {dif} salários mínimos')

#RAÍZ QUADRADA
#Calcule e imprima a raiz quadrada desse número e esse número elevado à quinta potência.
#import math
#n1 = int (input('Digite um número: '))

#print(math.sqrt(n1))

#Exemplo 2
#n1 = float(input('Digite a primeira nota: '))
#n2 = float(input('Digite a segunda nota:'))
#media = (n1 + n2)/2
#print(f'A média deste aluno é {media}')


#Exemplo 3
#cump = float(input('Digite o tamanho da barra em centímetro: '))
#pol = cump / 2.54
#print(f'O cumprimento em polegada é {pol}')

#pes = cump / 30.48
#print(f'O cumprimento em pés é {pes}')

#Exemplo 4
# while (True):
#   try:
#     larg = float (input('Digite a largura em metro: '))
#     alt = float (input('Digite a altura em metro: '))
#     cump = float (input('Digite o cumprimento em metro: '))
#     vol = larg * alt * cump

#     p_alcool = float (input('Digite o valor do álcool: R$'))
#     p_gasol = float (input('Digite o valor da gasolina: R$'))

#     alco = (vol*1000) * p_alcool
#     gasol = (vol*1000) * p_gasol
#     meio = (((vol*1000)*0.20)*p_alcool)+(((vol*1000)*0.80)*p_gasol)
#     print(f'Para encher o tanque de {vol * 1000}L de álcool você gastará R${alco }')
#     print(f'Para encher o tanque de {vol * 1000}L de gasolina você gastará R${gasol }')
#     print(f'Se você colocar 20% de álcool e 80% de gasolina você gastará R${meio }')
#   except Exception as erro:
#     print(f'Erro:{erro}')

# nome = input('Digite o seu nome: ')
# print(f'Prazer, {nome}')
# perg1 = input('Vamos começar?\n[1]-Sim\n[2]-Não')
# if (perg1 != 1):
#   print('Você está pronto para começar o jogo')
#   perg2 = input('Qual a capital da Itália?')
#   if perg2 == 'Roma':
#     print('Parabéns! Você acertou')
#   else:
#       print('Que pena, você errou')
# else:
#   print('Ok, até a próxima')

# aluno = input('Digite o nome do aluno: ')
# nota1 = float (input(f'Digita a primeira nota do {aluno}: '))
# nota2 = float (input(f'Digita a segunda nota do {aluno}: '))
# media = (nota1 + nota2) / 2
# print(f'O aluno {aluno} ficou com média: {media}')
# if (media < 3):
#   print(f'O aluno {aluno} ficou em REPROVADO DIRETO')
# elif (3 <= media and media <= 5):
#   print(f'O aluno {aluno} ficou em RECUPERAÇÃO')
# else:
#   print(f'O aluno {aluno} foi APROVADO DIRETO')


# GERAÇÃO Z = 15 a 20 ANOS
# GERAÇÃO Y = 21 A 34 ANOS
# GERAÇÃO X = 35 A 49 ANOS
# BABY BOOMERS = 50 A 64 ANOS
# GERAÇÃO SILENCIOSA = +65 ANOS

# idade = int(input('Digite a sua idade: '))
# if (15 <= idade and idade <= 20):
#   print(f'Você tem {idade} anos e faz parte da GERAÇÃO Z')
# elif (21 <= idade and idade <= 34):
#   print(f'Você tem {idade} anos e faz parte da GERAÇÃO Y')
# elif (35 <= idade and idade <= 49):
#   print(f'Você tem {idade} anos e faz parte da GERAÇÃO X')
# elif (50 <= idade and idade <= 64):
#   print(f'Você tem {idade} anos e faz parte dos BABY BOOMERS')
# else:
#   print(f'Você tem 65 anos ou mais! Faz parte da GERAÇÃO SILENCIOSA')
# Out:
# Digite a sua idade: 29
# Você tem 29 anos e faz parte da GERAÇÃO Y
